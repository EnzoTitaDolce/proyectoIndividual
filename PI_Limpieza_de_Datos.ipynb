# %%
#hacmeos las imporaciones necesarias
import pandas as pd
import numpy as np
from pandas import json_normalize #para convertir diccionarios y listas
import ast #para convettir strings en listas o diccionarios

# %%
#configuramos pandas para que muestre todas las columnas del dataframe
pd.set_option('display.max_columns',None)

#importamos el archivo csv
datos=pd.read_csv('../../PI MLOps-20230726T005937Z-001/PI MLOps/movies_dataset.csv')
# Out:
# C:\Users\kanza\AppData\Local\Temp\ipykernel_20000\3844907441.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos=pd.read_csv('../../PI MLOps-20230726T005937Z-001/PI MLOps/movies_dataset.csv')

# %%
#convertimos el archivo csv en un dataframe
data=pd.DataFrame(datos)

#vemos cuantas columnas tiene y la cantidad de valores no nulos del datafram
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
"completamos los valores faltantes dela columna revenue con el valor 0"
data['revenue'].fillna(0,inplace=True)

#volvemos a imprimir un resumen del dataframe para ver si la cantidad de valores nulos de la columna revenue cambió
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
#idem que con la columna revenue pero con la columna budget
data['budget'].fillna(0, inplace=True)
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
#eliminamos los valores faltantes pero solo de la columna release_date
data.dropna(subset=['release_date'],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45379 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45379 non-null  object
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45379 non-null  object
#  3   genres                 45379 non-null  object
#  4   homepage               7769 non-null   object
#  5   id                     45379 non-null  object
#  6   imdb_id                45365 non-null  object
#  7   original_language      45368 non-null  object
#  8   original_title         45379 non-null  object
#  9   overview               44438 non-null  object
#  10  popularity             45377 non-null  object
#  11  poster_path            45040 non-null  object
#  12  production_companies   45379 non-null  object
#  13  production_countries   45379 non-null  object
# ...

# %%
#hacemos una copia del dataset para probar el desanidamiento de datos
data2=data.copy()

#eliminamos las columnas innecesarias
eliminar=['video','imdb_id','adult','original_title','poster_path','homepage']
data2.drop(columns=eliminar, inplace=True)
data2
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45460                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %%
#la columna belongs_to_collection parece ser un diccionario pero es en realidad un string
type(data2['belongs_to_collection'][0])
# Out:
# str

# %%
#para convertira en diccionario usamos la librería ast
#los valores nulos en la columna belong_to_collection ocasionan un error en el método literal_eval
#para evitar eso los completamos el método fillna con una lista vacía
data2['belongs_to_collection'].fillna('[]',inplace=True)
data2['belongs_to_collection']=data2['belongs_to_collection'].apply(ast.literal_eval)

# %%
#idem con las otras columnas, primero completamos los valores faltantes con listas vacías
data2['genres'].fillna('[]',inplace=True)
data2['production_companies'].fillna('[]',inplace=True)
data2['production_countries'].fillna('[]',inplace=True)
data2['spoken_languages'].fillna('[]',inplace=True)

# %%
#aplicamos el método literal_eval a las columnas necesarias
columnas=['genres','production_companies','production_countries','spoken_languages']

data2[columnas]=data2[columnas].applymap(ast.literal_eval)
data2
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                     []  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                     []  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45460                                                 []         0
# 45462                                                 []         0
# 45463                                                 []         0
# 45464                                                 []         0
# 45465                                                 []         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %%
#verificamos que las columnas anteriores hayan cambiado su tipo de dato
type(data2['genres'][0])
# Out:
# list

# %%
#de la columna genre nos interesa el nombre del género más que su id
#prodcedemos a extraer el nombre del género de cada diccionario y a almacenarlo en una lista
#definimos la función
def extract_genre(genrelist):
    listageneros=[genre['name'] for genre in genrelist]
    return listageneros

#le aplicamos la función a la columna genres y guardamos la lista en una nueva columna

data2['genre_names']=data2['genres'].apply(extract_genre)

# %%
#la operación anterior funcionó
#aplicamos la misma idea a las otras columnas
data2[['belongs_to_collection','production_companies','production_countries','spoken_languages']]

#vemos que todas las columnas son diccionarios o listas de diccionarios y el atributo que nos interesa está guardado en la key name
# Out:
#                                    belongs_to_collection  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                     []
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                     []
# 4      {'id': 96871, 'name': 'Father of the Bride Col...
# ...                                                  ...
# 45460                                                 []
# 45462                                                 []
# 45463                                                 []
# 45464                                                 []
# 45465                                                 []
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# ...

# %%
#definimos una función para extraer el valor de las keys en caso de que las columnas sean diccionarios
def extract_dicts(diccionario):
    if type(diccionario)==dict:
        names=[diccionario['name']]
        return names    
    else:
        return []
    
#función para el caso en que el registro sea una lista de datos
def extract_list(lista):
    if type(lista)==list:
        names=[elemento['name'] for elemento in lista]
        return names
    else:
        return []

# %%
#aplicamos la función a las columnas correspondientes

data2['belongs_to_collection']=data2['belongs_to_collection'].apply(extract_dicts)
data2['production_companies']=data2['production_companies'].apply(extract_list)
data2['production_countries']=data2['production_countries'].apply(extract_list)
data2['spoken_languages']=data2['spoken_languages'].apply(extract_list)
data2
# Out:
#                   belongs_to_collection    budget  \
# 0                [Toy Story Collection]  30000000
# 1                                    []  65000000
# 2           [Grumpy Old Men Collection]         0
# 3                                    []  16000000
# 4      [Father of the Bride Collection]         0
# ...                                 ...       ...
# 45460                                []         0
# 45462                                []         0
# 45463                                []         0
# 45464                                []         0
# 45465                                []         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# ...

# %%
#extraemos el año de la columna release_date
data2['release_year']=data2['release_date'].str[:4]

# %%
#convertimos los string de la columna release_date a objetos del tipo date
data2['date']=pd.to_datetime(data2['release_date'],errors='coerce').dt.date
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kanza\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\kanza\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\kanza\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'release_date'
#
# ...

# %%
#eliminamos las columnas innecesarias
data2.drop('release_date',axis=1, inplace=True)

# %%
data2.drop('genres',axis=1,inplace=True)

# %%
#intentamos convertir la columna budget a float para poder calcular la columna return pero recibimos un error de valores imposibles de convertir
data2['budget']=data2['budget'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 data2['budget']=data2['budget'].astype(float)
#
# File c:\Users\kanza\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
'''son 3 valores inválidos, dada la naturaleza de los datos no conviene eliminarlos ya q no podemos asegurar que no tengan un gran impacto en el dataset
es decir, si fueran valores numéricos resultado de alguna medición quizás tendríamos otros resultados similares o iguales y eliminar 3 registros de un total de más de 45mil no tendríamos mucho error
pero quizás estos 3 registros son películas únicas entonces no deberíamos eliminarlas'''
resultados=data2[data2['budget'].str.contains(r'\D')]
resultados
# Out:
#       belongs_to_collection                            budget          id  \
# 19730                    []  /ff9qCepilowshEtG2GYWwzt2bs4.jpg  1997-08-20
# 29503                    []  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg  2012-09-29
# 35587                    []  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg  2014-01-01
#
#       original_language  overview             popularity production_companies  \
# 19730             104.0  Released                    NaN                   []
# 29503              68.0  Released                    NaN                   []
# 35587              82.0  Released  Beware Of Frost Bites                   []
#
#       production_countries  revenue  runtime spoken_languages status tagline  \
# 19730                   []      0.0      NaN               []    NaN     NaN
# 29503                   []      0.0      NaN               []    NaN     NaN
# 35587                   []      0.0      NaN               []    NaN     NaN
#
#       title  vote_average  vote_count  \
# ...

# %%
#usamos el método to_numeric de pandas para convertir la columna budget a float y reemplazar los valores inválidos por 0
data2['budget']=pd.to_numeric(data['budget'],errors='coerce').fillna(0).astype(float)

# %%
#creamos la columna return
data2['return']=data2['revenue']/data2['budget']

# %%
#reemplazamos los valores infinitos o nan con cer
data2['return'].replace([np.inf,-np.inf,np.nan],0, inplace=True)

# %%
data2
# Out:
#                   belongs_to_collection      budget      id original_language  \
# 0                [Toy Story Collection]  30000000.0     862                en
# 1                                    []  65000000.0    8844                en
# 2           [Grumpy Old Men Collection]         0.0   15602                en
# 3                                    []  16000000.0   31357                en
# 4      [Father of the Bride Collection]         0.0   11862                en
# ...                                 ...         ...     ...               ...
# 45460                                []         0.0   30840                en
# 45462                                []         0.0  111109                tl
# 45463                                []         0.0   67758                en
# 45464                                []         0.0  227506                en
# 45465                                []         0.0  461257                en
#
# ...

# %%
data2.drop('release_year',axis=1,inplace=True)

# %%
#guardamos el dataset limpio en un archivo csv
data2.to_csv('cleandata.csv', index=False)
